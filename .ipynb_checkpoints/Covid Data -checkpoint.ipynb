# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mpl_dates
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from matplotlib.ticker import MultipleLocator
#import featuretools as ft 
import xgboost as xgb
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
import joblib
import warnings

warnings.simplefilter(action='ignore', category=Warning)

# %% [markdown]
#
# This project is aimed to predict COVID-19 new cases and to learn more about machine learning  model to forecast cases in the future.
#
# Why am I using XGBoost? I chose XGBoost for this project because I wanted to apply the fundamentals of gradiant    boosting, decision trees and regressions. XGBoost objective function is the psuedo residuals and regulizations for the regression to fix the bias and variance of the models on the training set. Also, this model gave me an opporunity to use grid search to find the best parameters for the training set.
#
# Using XGBoost to predict a time related data was challenging and I expirtmented with different lags of confirmed cases so the model can understand the correlation between the time and the new confirmed cases.

# %%
#github data source 

ECDC = pd.read_csv("/Users/anuragshrestha/Desktop/covid-19-data/public/data/ecdc/COVID-2019 - ECDC (2020).csv")
full_data = pd.read_csv('/Users/anuragshrestha/Desktop/covid-19-data/public/data/ecdc/full_data.csv') 
df_locations = pd.read_csv('/Users/anuragshrestha/Desktop/covid-19-data/public/data/ecdc/locations.csv')
NewCases = pd.read_csv('/Users/anuragshrestha/Desktop/covid-19-data/public/data/ecdc/new_cases.csv')
Deaths = pd.read_csv("/Users/anuragshrestha/Desktop/covid-19-data/public/data/ecdc/total_deaths.csv")

ecdc_lastest = pd.read_csv('/Users/anuragshrestha/Desktop/covid-19-data/input/ecdc/releases/latest.csv')


#kaggle Covid19 forecasting challenge data sets 

train_set = pd.read_csv('/Users/anuragshrestha/Desktop/countryinfo/covid19-global-forecasting-week-3/train.csv')
test_set = pd.read_csv('/Users/anuragshrestha/Desktop/countryinfo/covid19-global-forecasting-week-3/test.csv')
submission = pd.read_csv('/Users/anuragshrestha/Desktop/countryinfo/covid19-global-forecasting-week-3/submission.csv')

#datasets from the community 

CountryInfo = pd.read_csv('/Users/anuragshrestha/Desktop/countryinfo/covid19countryinfo.csv')
CountryTest = pd.read_csv('/Users/anuragshrestha/Desktop/countryinfo/covid19tests.csv')
LocationInfo = pd.read_csv('/Users/anuragshrestha/Desktop/countryinfo/locations_population.csv')
Recovered = pd.read_csv('/Users/anuragshrestha/Desktop/countryinfo/novel-corona-virus-2019-dataset/covid_19_data.csv')
NewCountry = pd.read_csv('/Users/anuragshrestha/Desktop/countryinfo/population_by_country_2020.csv')

# %% [markdown]
#                                    Exploratory data analysis

# %% [markdown]
#     Questions: which countries have the most confirmed cases and how fast was the spread?

# %%
TopCases = train_set.groupby(['Date', 'Country_Region'])['ConfirmedCases', 'Fatalities'].sum().reset_index()
TopCases.sort_values(by = ['ConfirmedCases', 'Date'], ascending = False).head(10)
# Out:
#              Date Country_Region  ConfirmedCases  Fatalities
# 12948  2020-04-02             US        243295.0      5922.0
# 12768  2020-04-01             US        213214.0      4753.0
# 12588  2020-03-31             US        188018.0      3870.0
# 12408  2020-03-30             US        161655.0      2975.0
# 12228  2020-03-29             US        140734.0      2464.0
# 12048  2020-03-28             US        121326.0      2023.0
# 12864  2020-04-02          Italy        115242.0     13915.0
# 12933  2020-04-02          Spain        112065.0     10348.0
# 12684  2020-04-01          Italy        110574.0     13155.0
# 12504  2020-03-31          Italy        105792.0     12428.0

# %%
#top 3 countries with confirmed cases 

f, ax=plt.subplots(figsize=(10,5))

US= TopCases.loc[(TopCases['Country_Region']== 'US')]
Italy = TopCases.loc[(TopCases['Country_Region']== 'Italy')]
Spain = TopCases.loc[(TopCases['Country_Region']== 'Spain')]

plt.plot(US['Date'],US['ConfirmedCases'],linewidth=1.5,label='US')
plt.plot(Italy['Date'],Italy['ConfirmedCases'],linewidth=1.5, label = 'Italy')
plt.plot(Spain['Date'],Spain['ConfirmedCases'],linewidth=1.5, label = 'Spain')
plt.xticks(rotation=40)
ax.xaxis.set_major_locator(MultipleLocator(15))
ax.set(title='Number of top confirmed cases')
plt.legend()
plt.show()

f, ax=plt.subplots(figsize=(10,5))

plt.plot(US['Date'],US['Fatalities'],linewidth=1.5,label='US')
plt.plot(Italy['Date'],Italy['Fatalities'],linewidth=1.5, label = 'Italy')
plt.plot(Spain['Date'],Spain['Fatalities'],linewidth=1.5, label = 'Spain')
ax.set(title='Number of top fatalities')
ax.xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation  = 40)
plt.legend()
plt.show()

# %%
Max_CC = train_set.groupby(['Country_Region'],as_index=True).agg({'ConfirmedCases': 'max', 'Fatalities': 'max'})
train_data_confirm = Max_CC.sort_values(by=["ConfirmedCases"], ascending=False)

train_data_confirm.head(10).plot(figsize=(13,8), kind='barh')
plt.legend(["Confirmed Cases", "Fatalities"]);
plt.xlabel("Number of Covid-19 Cases")
plt.title("TOP 10 Countries with Confirmed Cases")
plt.show()

# %% [markdown]
#              Data Pre-processing

# %% [markdown]
# Using the dataset about the world's population and information to find valuable informations about how fast the virus can spread to each country. Also, density, urban population and density can play a role on the spread of the coronavirus

# %%
#adding population, density, land area, Migrants, Median Age and Urban Pop to the train set 
NewCountry = NewCountry.rename(columns= {'Country (or dependency)': 'Country', "Population (2020)": 'Population', 'Med. Age': 'Median Age'})
NewCountry['Country'] = NewCountry.Country.replace({'United States': 'US'})

#stripping the percentage 
NewCountry['Urban Pop %'] = NewCountry['Urban Pop %'].str.rstrip('%')

#changing the missing values with the mode of the column
NewCountry.loc[NewCountry['Urban Pop %']=='N.A.', 'Urban Pop %'] = int(NewCountry.loc[NewCountry['Urban Pop %']!='N.A.', 'Urban Pop %'].mode()[0])
NewCountry['Urban Pop %'] = NewCountry['Urban Pop %'].astype('int16')

# values are as percentage of the total population 
NewCountry['Urban Pop %'] = NewCountry['Urban Pop %'] / 100

#filling the missing value 
NewCountry.loc[NewCountry['Median Age']=='N.A.', 'Median Age'] = int(NewCountry.loc[NewCountry['Median Age']!='N.A.', 'Median Age'].mode()[0])
NewCountry['Median Age'] = NewCountry['Median Age'].astype('int16')

NewCountry.dtypes
NewCountry = NewCountry.drop(columns = ['World Share', 'Yearly Change', 'Net Change', 'Fert. Rate'])

#changing the NaN values on the test and train sets to 'none'
#for df in [train_set, test_set]: 
 #   df['Province_State'].fillna(value = 'None', inplace = True)

train_set = train_set.merge(NewCountry, left_on='Country_Region', right_on='Country', how='left').drop(columns = 'Country').reset_index(drop = True)
test_set = test_set.merge(NewCountry, left_on='Country_Region', right_on='Country', how='left').drop(columns = 'Country').reset_index(drop = True)

train_set['Date'] = pd.to_datetime(train_set['Date'], format = '%Y-%m-%d')
test_set['Date'] = pd.to_datetime(test_set['Date'], format = '%Y-%m-%d')

# %%
#getting days, months, and years
def dayMonth(df):
    df['Month'] = df['Date'].dt.month
    df['Day'] = df['Date'].dt.day  
    return df


def Percentage(df): 
    df['%CasesinPop'] = df['ConfirmedCases'] / df['Population']#% of population with corona cases
    df['%FatalitiesinPop'] = df['Fatalities'] / df['Population'] 
    
    return df 

Percentage(train_set)

for df in [train_set, test_set]: 
    dayMonth(df)
train_set
# Out:
#           Id Province_State Country_Region       Date  ConfirmedCases  \
# 0          1            NaN    Afghanistan 2020-01-22             0.0
# 1          2            NaN    Afghanistan 2020-01-23             0.0
# 2          3            NaN    Afghanistan 2020-01-24             0.0
# 3          4            NaN    Afghanistan 2020-01-25             0.0
# 4          5            NaN    Afghanistan 2020-01-26             0.0
# ...      ...            ...            ...        ...             ...
# 22027  32703            NaN       Zimbabwe 2020-03-29             7.0
# 22028  32704            NaN       Zimbabwe 2020-03-30             7.0
# 22029  32705            NaN       Zimbabwe 2020-03-31             8.0
# 22030  32706            NaN       Zimbabwe 2020-04-01             8.0
# 22031  32707            NaN       Zimbabwe 2020-04-02             9.0
#
#        Fatalities  Population  Density (P/Km²)  Land Area (Km²)  \
# 0             0.0  38928346.0             60.0         652860.0
# 1             0.0  38928346.0             60.0         652860.0
# 2             0.0  38928346.0             60.0         652860.0
# 3             0.0  38928346.0             60.0         652860.0
# 4             0.0  38928346.0             60.0         652860.0
# ...           ...         ...              ...              ...
# 22027         1.0  14862924.0             38.0         386850.0
# 22028         1.0  14862924.0             38.0         386850.0
# 22029         1.0  14862924.0             38.0         386850.0
# 22030         1.0  14862924.0             38.0         386850.0
# 22031         1.0  14862924.0             38.0         386850.0
#
#        Migrants (net)  Median Age  Urban Pop %   %CasesinPop  \
# 0            -62920.0        18.0         0.25  0.000000e+00
# 1            -62920.0        18.0         0.25  0.000000e+00
# 2            -62920.0        18.0         0.25  0.000000e+00
# 3            -62920.0        18.0         0.25  0.000000e+00
# 4            -62920.0        18.0         0.25  0.000000e+00
# ...               ...         ...          ...           ...
# 22027       -116858.0        19.0         0.38  4.709706e-07
# 22028       -116858.0        19.0         0.38  4.709706e-07
# 22029       -116858.0        19.0         0.38  5.382521e-07
# 22030       -116858.0        19.0         0.38  5.382521e-07
# 22031       -116858.0        19.0         0.38  6.055336e-07
#
#        %FatalitiesinPop  Month  Day
# 0          0.000000e+00      1   22
# 1          0.000000e+00      1   23
# 2          0.000000e+00      1   24
# 3          0.000000e+00      1   25
# 4          0.000000e+00      1   26
# ...                 ...    ...  ...
# 22027      6.728151e-08      3   29
# 22028      6.728151e-08      3   30
# 22029      6.728151e-08      3   31
# 22030      6.728151e-08      4    1
# 22031      6.728151e-08      4    2
#
# [22032 rows x 16 columns]

# %%
#creating cases and fatalities per week, and month 

#train_set['Date'] = pd.to_datetime(train_set['Date']) - pd.to_timedelta(7, unit='d')

#Weeklycases = train_set.groupby(['Country_Region', pd.Grouper(key='Date', freq='W-MON')])['ConfirmedCases','Fatalities'].sum().reset_index().sort_values('Date')

#Weeklycases = Weeklycases.rename(columns = {'Country_Region': 'Country','ConfirmedCases': 'WeeklyCases', 'Fatalities': 'WeeklyFatalities'})

# %%
#adding lags on the training set to find the growth of the cases and fatalities during the time 

lag = [1,2,3,4,5,6]
col= ['Confirmed_Cases', 'Fatalities']

for l in lag:
    train_set["ConfirmedCases" +str(l)] = train_set["ConfirmedCases"].shift(l).fillna(0)
    train_set["Fatalities"+str(l)] = train_set["Fatalities"].shift(l).fillna(0)
    
#acf(train_set['ConfirmedCases'], nlags = 4)


plot_acf(train_set['ConfirmedCases']) #what does the acf tell us? 

plot_pacf(train_set['ConfirmedCases'], lags = 10)

# %%
#encoding the country and states into numerical values 
#replacing the missing province state with just country name for now 

def encoder(df): 
    df.Province_State.fillna(value = 'None', inplace = True)
    label_maker = OrdinalEncoder()
    df[['Province_State','Country_Region']] = label_maker.fit_transform(df.loc[:,['Province_State','Country_Region']])
    #df.loc[:, 'Date'] = df['Date'].dt.strftime("%m%d")
    #df['Date'] = df['Date'].astype('int')
    return df 

for df in [train_set, test_set]:
    encoder(df)

# %%
#features for now 

target1 = ['ConfirmedCases']
target2 = ['Fatalalities']

features_Cases = ['Month', 
                  'Day',  #not using days at all 
                  'Population', 
                 # 'Country_Region',
                 # 'Province_State',
                  #'Density (P/Km²)' 
                  #,'Land Area (Km²)', 
                  #'Migrants (net)',
                 # 'Median Age',
                 # 'Urban Pop',
                   "%CasesinPop",
                  'ConfirmedCases1', 
                  "ConfirmedCases2", 
                  'ConfirmedCases3',
                  'ConfirmedCases4',
                  'ConfirmedCases5', 'ConfirmedCases6']
        
parameters = {'learning_rate': .07, 
                      'max_depth': 2,
                      'min_child_weight': 5,
                      'colsample_bytree': .5,
                      'reg_alpha': 1,
                      'reg_lambda': 4,
                      'n_estimators': 1000}




for country in train_set['Country_Region'].unique(): 
    xtrain1 = train_set[train_set['Country_Region'] == country]
    
    for state in xtrain1.Province_State.unique(): 
        xtrain2 = xtrain1[xtrain1['Province_State'] == state]
        
        Train_set = xtrain2[xtrain2['Date'] < '2020-03-02']
        valid_set = xtrain2[(xtrain2['Date'] >= '2020-03-02') & (xtrain2['Date'] < '2020-03-26')] 
        Test_set = xtrain2[xtrain2['Date'] >= '2020-03-26']
        
        X_train = train_set[features_Cases].values
        X_valid = valid_set[features_Cases].values
        X_test = Test_set[features_Cases].values

        y_train = np.log(train_set[target1].values.clip(0, 1e10)+1)
        y_val = np.log(valid_set[target1].values.clip(0, 1e10)+1)
        x_test = np.log(Test_set[target1].values.clip(0,1e10)+1)
        

        
        model = xgb.XGBRFRegressor(**parameters,objective ='reg:squarederror')


#find the parameters through grid search? 


#xgb_grid = GridSearchCV(xgb,parameters, cv = 2, n_jobs = 2, verbose=True)

#xgb_grid.fit(X_train, y_train)

#print(xgb_grid.best_score_) #0.9794510916798058 0.979984356266905 
#print(xgb_grid.best_params_)

#{'colsample_bytree': 0.5, 
#'learning_rate': 0.07, 'max_depth': 2, 'n_estimators': 1000, 'reg_alpha': 2, 'reg_lambda': 1}

        model.fit(X_train,y_train, eval_metric = 'rmse', eval_set = [(X_train, y_train),(X_valid, y_val)], early_stopping_rounds = 5, verbose=True)
# Out:
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.00451
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.66968
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.13931
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.30333
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.522495
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.442247
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.1152
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.81895
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.30157
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.08671
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.634391
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.35447
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.569
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.49708
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.36549
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.54315
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:5.51958
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.40705
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.663039
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.29958
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.65259
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.08163
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.53666
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:5.56545
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.458422
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.633905
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.345329
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.58386
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.56126
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.469808
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.35641
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.62881
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.91337
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.1067
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.476715
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.469808
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.56882
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.15276
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.72302
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.08142
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.73855
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.49053
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.3008
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.19692
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.469808
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.61879
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.88841
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.546706
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.19622
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.7577
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.469808
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.536404
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.468365
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.72748
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:6.00646
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:5.2349
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:5.46609
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.81421
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.02516
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:6.33158
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.66763
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.19334
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.33167
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.87346
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:5.28784
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:6.25749
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.29842
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:10.2304
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:6.03432
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.53643
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:5.55768
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:5.94954
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.74762
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.0412
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.00648
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.53424
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.19742
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.65043
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:5.74363
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.99537
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.1014
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:5.40139
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.13066
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.188365
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.54842
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.37045
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:6.21854
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.97127
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.617971
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.52289
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.74489
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.48693
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.24318
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.61009
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.511
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.43645
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.4092
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.625138
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:5.07617
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:5.69024
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.599554
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.552202
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.57843
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.61288
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.75346
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.652671
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.917878
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.477832
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.58278
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.545411
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.1058
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.551248
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.12103
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.58593
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.27094
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.94759
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.90542
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.21292
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.83804
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.95501
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.661695
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.865538
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:7.29451
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.681165
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.459731
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.48211
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:7.45224
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.61035
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.37056
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.435145
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.2993
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.513896
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.475748
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.1015
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.693652
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.384553
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.53588
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.7775
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.18182
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.88458
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.73202
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:8.34181
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.87028
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.13937
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.40079
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:8.86905
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.53613
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:5.62971
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.37584
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.1018
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.19519
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:8.058
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.476715
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.83205
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.26816
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.495869
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.76659
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.61518
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.546937
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.453166
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.76302
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.41544
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.66314
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.476715
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.923975
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.93723
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.56761
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.475748
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.43429
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.440809
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.40714
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.1125
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.3642
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.3289
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.0257
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.38094
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.56014
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.528573
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.709494
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.270318
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.00473
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.687686
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.469633
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:5.85398
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.26712
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.465486
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.572972
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.49626
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.46626
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:5.6477
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.59095
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.79112
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.048
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.415978
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.54704
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.2979
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.68046
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.86205
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.52064
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.22386
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.81242
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.50671
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.47911
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.483635
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.530769
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.363061
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.50474
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.71206
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.24815
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.01793
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.936486
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.469808
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.61527
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.9769
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.85215
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.374633
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.21274
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:7.52332
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.34086
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.478019
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.727091
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:5.49331
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:6.29739
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.504657
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.56897
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.00814
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.14867
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.435145
# ...
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.4664
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.62815
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.38428
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.63569
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.57504
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.7208
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.70152
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.07715
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.02846
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.43483
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.93026
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.70363
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.42098
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.87385
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.80083
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.87873
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.78032
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.41154
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.11046
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.44715
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.80347
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.27618
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.9905
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.03072
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.61261
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.83362
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.57559
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.30429
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.64942
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.086
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.84824
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.22536
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.23552
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.16293
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:5.84
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.07648
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.50233
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.11265
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.12975
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.88877
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.53387
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.49174
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.35294
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.87834
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.65567
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.32335
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.63624
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.7364
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.96293
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.905631
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.9911
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:4.97858
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.16502
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.14412
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.5395
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.787788
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.95314
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.65986
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.469808
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.719653
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.469808
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.680357
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.55577
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.18103
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.970819
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.396518
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.469808
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:6.04677
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.45207
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:1.77679
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.14349
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:3.14232
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:2.59138
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.66175
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [0]	validation_0-rmse:2.73	validation_1-rmse:0.553811
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.

# %%
joblib.dump(model, 'xgb.joblib.dat')
# Out:
# ['xgb.joblib.dat']

# %%
#graph of feature importance 

plt.bar(range(len(model.feature_importances_)), model.feature_importances_)
plt.xlabel("Features")
plt.ylabel("Features Importance")
plt.show()


#results of validation 
results = model.evals_result()
epochs = len(results['validation_0']['rmse'])
epochs
#fig, ax = plt.subplots(figsize = (15,10))
#x_axis = range(epochs)
#ax.plot(x_axis, results['validation_0']['rmse'], label='Train')
#ax.plot(x_axis, results['validation_1']['rmse'], label='Test')
#ax.legend()
#plt.ylabel("RMSE")
#plt.show()
# Out:
# 1

# %%
score = model.get_booster().get_fscore()

score = pd.Series(score, name='featureScore')
score.index.name = 'Feature'
score = score.reset_index()
score = pd.DataFrame(score)
score = score.sort_values(by = ['featureScore'], ascending = True)
score
# Out:
#   Feature  featureScore
# 8      f2             9
# 7      f9            15
# 5      f8            73
# 3      f0           149
# 6      f7           165
# 2      f6           320
# 4      f3           483
# 0      f5           550
# 1      f4          1236

# %%
#Model building 

#get unique values for the coutries 
        
#XGB_2 = XGB_1
#XGB_2.fit(x_train, y_train2, eval_metric="rmse",eval_set=[(x_train, y_train), (x_cv, y_cv2)] )    #for fatalities 
        
       # xtest1 = test_set[(test_set['Country_Region'] == country) & (test_set['Province_State'] == state)]
        #ForeCastID = xtest1.Id.values 
        
        # xtest2 = xtest1[features_test].values
        
       # predictions of 2 output in the matrix
        #cases_pred = np.round(XGB_1.predict(xtest2),5)
        #death_pred = np.round(XGB_2.predict(xtest2),5)
        
        #Append the predicted values to submission list
       # for i in range(len(cases_pred)):
        #    d = {'ForecastId': ForeCastID[i], 'ConfirmedCases': cases_pred[i], 'Fatalities':death_pred[i]}
         #   prediction.append(d)

# %%
#submission = pd.DataFrame(prediction)

#submission.to_csv('BasePrediction.csv', index = False)
